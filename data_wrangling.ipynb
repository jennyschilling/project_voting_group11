# %% [markdown]
# <a href="https://colab.research.google.com/github/jennyschilling/project_voting_group11/blob/main/data_wrangling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! rm -r project_voting_group11/

# %%
# !git clone https://github.com/jennyschilling/project_voting_group11
# Out:
# Cloning into 'project_voting_group11'...
# remote: Enumerating objects: 93, done.
# remote: Counting objects: 100% (23/23), done.
# remote: Compressing objects: 100% (17/17), done.
# remote: Total 93 (delta 11), reused 10 (delta 6), pack-reused 70
# Receiving objects: 100% (93/93), 34.99 MiB | 19.61 MiB/s, done.
# Resolving deltas: 100% (36/36), done.

# %%
import pandas as pd
import numpy as np

# %%
demographics_data = pd.read_csv('./project_voting_group11/data/va_2016-20_demographics.csv')
voting_data = pd.read_csv('./project_voting_group11/data/voting_VA_2020.csv')

(demographics_data.head(), voting_data.head())
# Out:
# (    GISJOIN       YEAR STUSAB  REGIONA  DIVISIONA     STATE  STATEA  \
#  0  G5100010  2016-2020     VA      NaN        NaN  Virginia      51
#  1  G5100030  2016-2020     VA      NaN        NaN  Virginia      51
#  2  G5100050  2016-2020     VA      NaN        NaN  Virginia      51
#  3  G5100070  2016-2020     VA      NaN        NaN  Virginia      51
#  4  G5100090  2016-2020     VA      NaN        NaN  Virginia      51
#
#               COUNTY  COUNTYA  COUSUBA  ...  AM8FE031  AM8FE032  AM8FE033  \
#  0   Accomack County        1      NaN  ...      6474       823      5651
#  1  Albemarle County        3      NaN  ...     20763      1248     19515
#  2  Alleghany County        5      NaN  ...      3052       523      2529
#  3     Amelia County        7      NaN  ...      2667       379      2288
#  4    Amherst County        9      NaN  ...      6596       771      5825
#
#     AM8FE034  AM8FE035  AM8FE036  AM8FE037  AM8FE038  AM8FE039  AM9SE001
#  0      2376       426      1950      1683       920       763    0.4562
#  1      6183       723      5460      4898      2124      2774    0.4719
#  2      1071       288       783       836       442       394    0.4537
#  3       746       114       632       570       265       305    0.4320
#  4      2009       472      1537      1636       695       941    0.4239
#
#  [5 rows x 161 columns],
#     Unnamed: 0  year     state state_po county_name  county_fips        office  \
#  0       70379  2020  VIRGINIA       VA    ACCOMACK        51001  US PRESIDENT
#  1       70380  2020  VIRGINIA       VA    ACCOMACK        51001  US PRESIDENT
#  2       70381  2020  VIRGINIA       VA    ACCOMACK        51001  US PRESIDENT
#  3       70382  2020  VIRGINIA       VA    ACCOMACK        51001  US PRESIDENT
#  4       70383  2020  VIRGINIA       VA    ACCOMACK        51001  US PRESIDENT
#
#             candidate        party  candidatevotes  totalvotes   version  \
#  0  JOSEPH R BIDEN JR     DEMOCRAT            5495       16962  20220315
#  1  JOSEPH R BIDEN JR     DEMOCRAT            2072       16962  20220315
#  2  JOSEPH R BIDEN JR     DEMOCRAT              11       16962  20220315
#  3       JO JORGENSEN  LIBERTARIAN              66       16962  20220315
#  4       JO JORGENSEN  LIBERTARIAN             122       16962  20220315
#
#             mode
#  0      ABSENTEE
#  1  ELECTION DAY
#  2   PROVISIONAL
#  3      ABSENTEE
#  4  ELECTION DAY  )

# %%
# We need to merge these two files on the county names, so we have to get the names
# formatted in the same manner first
def format_county_name(county_name):
    county_name = county_name.replace(" County", "")
    return county_name.upper()

demographics_data['COUNTY'] = demographics_data['COUNTY'].apply(format_county_name)
demographics_data.head()
# Out:
#     GISJOIN       YEAR STUSAB  REGIONA  DIVISIONA     STATE  STATEA  \
# 0  G5100010  2016-2020     VA      NaN        NaN  Virginia      51
# 1  G5100030  2016-2020     VA      NaN        NaN  Virginia      51
# 2  G5100050  2016-2020     VA      NaN        NaN  Virginia      51
# 3  G5100070  2016-2020     VA      NaN        NaN  Virginia      51
# 4  G5100090  2016-2020     VA      NaN        NaN  Virginia      51
#
#       COUNTY  COUNTYA  COUSUBA  ...  AM8FE031  AM8FE032  AM8FE033  AM8FE034  \
# 0   ACCOMACK        1      NaN  ...      6474       823      5651      2376
# 1  ALBEMARLE        3      NaN  ...     20763      1248     19515      6183
# 2  ALLEGHANY        5      NaN  ...      3052       523      2529      1071
# 3     AMELIA        7      NaN  ...      2667       379      2288       746
# 4    AMHERST        9      NaN  ...      6596       771      5825      2009
#
#    AM8FE035  AM8FE036  AM8FE037  AM8FE038  AM8FE039  AM9SE001
# 0       426      1950      1683       920       763    0.4562
# 1       723      5460      4898      2124      2774    0.4719
# 2       288       783       836       442       394    0.4537
# 3       114       632       570       265       305    0.4320
# 4       472      1537      1636       695       941    0.4239
#
# [5 rows x 161 columns]

# %%
# Now we can merge the two datasets on the county name
merged_df = pd.merge(voting_data, demographics_data, left_on='county_name', right_on='COUNTY')
merged_df.to_csv('./project_voting_group11/data/merged.csv', index=False)
merged_df.head()
# Out:
#    Unnamed: 0  year     state state_po county_name  county_fips        office  \
# 0       70379  2020  VIRGINIA       VA    ACCOMACK        51001  US PRESIDENT
# 1       70380  2020  VIRGINIA       VA    ACCOMACK        51001  US PRESIDENT
# 2       70381  2020  VIRGINIA       VA    ACCOMACK        51001  US PRESIDENT
# 3       70382  2020  VIRGINIA       VA    ACCOMACK        51001  US PRESIDENT
# 4       70383  2020  VIRGINIA       VA    ACCOMACK        51001  US PRESIDENT
#
#            candidate        party  candidatevotes  ...  AM8FE031  AM8FE032  \
# 0  JOSEPH R BIDEN JR     DEMOCRAT            5495  ...      6474       823
# 1  JOSEPH R BIDEN JR     DEMOCRAT            2072  ...      6474       823
# 2  JOSEPH R BIDEN JR     DEMOCRAT              11  ...      6474       823
# 3       JO JORGENSEN  LIBERTARIAN              66  ...      6474       823
# 4       JO JORGENSEN  LIBERTARIAN             122  ...      6474       823
#
#   AM8FE033 AM8FE034 AM8FE035 AM8FE036  AM8FE037  AM8FE038 AM8FE039  AM9SE001
# 0     5651     2376      426     1950      1683       920      763    0.4562
# 1     5651     2376      426     1950      1683       920      763    0.4562
# 2     5651     2376      426     1950      1683       920      763    0.4562
# 3     5651     2376      426     1950      1683       920      763    0.4562
# 4     5651     2376      426     1950      1683       920      763    0.4562
#
# [5 rows x 174 columns]
